# %%
import tushare as ts

# %%
df = ts.get_hist_data('510050')

# %%
df
# Out:
#              open   high  close    low      volume  price_change  p_change  \
# date
# 2017-10-19  2.800  2.810  2.810  2.800  3276864.50         0.010      0.36
# 2017-10-18  2.780  2.810  2.800  2.780  6735698.50         0.020      0.72
# 2017-10-17  2.780  2.790  2.780  2.770  2424663.25         0.000      0.00
# 2017-10-16  2.770  2.790  2.780  2.770  3127203.50         0.010      0.36
# 2017-10-13  2.770  2.780  2.770  2.770  1618771.12         0.000      0.00
# 2017-10-12  2.760  2.780  2.770  2.750  2035754.00         0.010      0.36
# 2017-10-11  2.750  2.770  2.760  2.750  3333772.00         0.010      0.36
# 2017-10-10  2.750  2.760  2.750  2.730  5950614.50         0.000      0.00
# 2017-10-09  2.790  2.800  2.750  2.740  5753671.50         0.020      0.73
# 2017-09-29  2.720  2.740  2.730  2.720  4708403.00         0.010      0.37
# 2017-09-28  2.710  2.720  2.720  2.700  2659988.75         0.010      0.37
# ...

# %%
df = ts.get_tick_data('510050',date='2017-10-11')

# %%
df
# Out:
#           time  price change  volume   amount type
# 0     15:00:00  2.762     --       0        0   买盘
# 1     15:00:00  2.762     --       0        0   买盘
# 2     15:00:00  2.762     --     266    73469   买盘
# 3     14:59:59  2.761     --     323    89180   卖盘
# 4     14:59:57  2.762     --    2313   638850   买盘
# 5     14:59:54  2.762     --     165    45573   买盘
# 6     14:59:51  2.762     --    1540   425348   买盘
# 7     14:59:48  2.762     --      40    11048   买盘
# 8     14:59:45  2.762     --     800   220960   买盘
# 9     14:59:42  2.762     --     305    84241   买盘
# 10    14:59:39  2.762     --     150    41430   买盘
# 11    14:59:36  2.762     --     115    31763   买盘
# 12    14:59:33  2.762     --    1126   311001   买盘
# 13    14:59:30  2.762     --     103    28448   买盘
# 14    14:59:27  2.761     --    1120   309232   卖盘
# 15    14:59:24  2.761     --    3117   860603   卖盘
# 16    14:59:21  2.762     --    3000   828600   买盘
# ...

# %%
df = ts.get_today_all()
df
# Out:
# [Getting data:]############################################################
#         code   name  changepercent   trade    open    high     low  \
# 0     603999   读者传媒         -4.199    9.81   10.16   10.22    9.79
# 1     603998   方盛制药          1.771   14.37   14.12   14.39   14.03
# 2     603997   继峰股份         -1.111   12.46   12.60   12.72   12.40
# 3     603996   中新科技         -2.784   16.76   17.35   17.41   16.54
# 4     603993   洛阳钼业          0.445    6.77    6.70    6.92    6.55
# 5     603991   至正股份         -2.442   33.56   34.31   34.43   33.50
# 6     603990   麦迪科技         -2.565   37.60   38.51   38.79   37.40
# 7     603989   艾华集团         -0.330   36.19   36.11   36.50   36.11
# 8     603988   中电电机         -1.272   69.06   71.08   71.08   68.85
# 9     603987    康德莱          3.060   16.84   16.20   17.17   16.20
# 10    603986   兆易创新         -8.431  115.78  125.50  126.86  115.00
# 11    603985   恒润股份         -2.028   45.89   46.77   46.77   45.66
# ...

# %%
df = ts.get_today_ticks('510050')
df
# Out:
# http://vip.stock.finance.sina.com.cn/quotes_service/api/json_v2.php/CN_Transactions.getAllPageTime?date=2017-10-19&symbol=sh510050
# [Getting data:]#http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=1
# #http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=2
# #http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=3
# #http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=4
# #http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=5
# #http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=6
# #http://vip.stock.finance.sina.com.cn/quotes_service/view/vMS_tradedetail.php?symbol=sh510050&date=2017-10-19&page=7
# ...

# %%
df = ts.get_hist_data('510050')
df.to_csv('data.csv')

# %%
import json
import pymongo

data = json.loads(df.to_json(orient='records'))
#print data

c = pymongo.MongoClient('localhost', 27017)
db = c['testdb']
col = db['testcollection']
col.insert_one(data)
